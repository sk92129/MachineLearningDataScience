# %%
import pandas as pd

# %%
import csv

# %%
babyNames=pd.read_csv("babyNames.csv")

# %%
babyNames.head()
# Out:
#   State Sex  Year      Name  Count
# 0    CA   F  1910      Mary    295
# 1    CA   F  1910     Helen    239
# 2    CA   F  1910   Dorothy    220
# 3    CA   F  1910  Margaret    163
# 4    CA   F  1910   Frances    134

# %%
babyNames["Name"]
# Out:
# 0             Mary
# 1            Helen
# 2          Dorothy
# 3         Margaret
# 4          Frances
#             ...
# 387776     Zayvion
# 387777        Zeek
# 387778      Zhaire
# 387779        Zian
# 387780       Ziyad
# Name: Name, Length: 387781, dtype: object

# %%
namesCol = babyNames["Name"]
type(namesCol)
# Out:
# pandas.core.series.Series

# %%
dfSub = babyNames[["Name", "Count"]]
type(dfSub)
# Out:
# pandas.core.frame.DataFrame

# %%
result = babyNames[0:1]
type(result)
# Out:
# pandas.core.frame.DataFrame

# %%
result
# Out:
#   State Sex  Year  Name  Count
# 0    CA   F  1910  Mary    295

# %%
j_names_bool_list = [ x.startswith('J') for x in babyNames['Name'] ]

# %%
j_names_list = babyNames[j_names_bool_list]

# %%
j_names_list
# Out:
#        State Sex  Year         Name  Count
# 16        CA   F  1910    Josephine     66
# 44        CA   F  1910         Jean     35
# 46        CA   F  1910       Jessie     32
# 59        CA   F  1910        Julia     28
# 66        CA   F  1910      Juanita     25
# ...      ...  ..   ...          ...    ...
# 387597    CA   M  2019  Joseantonio      5
# 387598    CA   M  2019       Jovian      5
# 387599    CA   M  2019       Jujhar      5
# 387600    CA   M  2019      Jullian      5
# 387601    CA   M  2019         June      5
#
# [33400 rows x 5 columns]

# %%
babyNames[babyNames["Name"].str.endswith("ert")]['Name'].unique()
# Out:
# array(['Robert', 'Gilbert', 'Albert', 'Herbert', 'Bert', 'Hubert',
#        'Delbert', 'Elbert', 'Wilbert', 'Norbert', 'Rupert', 'Filbert',
#        'Adelbert', 'Evert', 'Calvert', 'Lambert', 'Hilbert', 'Philbert',
#        'Engelbert', 'Levert', 'Robbert', 'Johnrobert', 'Mert'],
#       dtype=object)

# %%
type(babyNames["Name"].str.startswith('J'))
# Out:
# pandas.core.series.Series

# %%
babyNames[babyNames["Name"].str.startswith('J')]
# Out:
#        State Sex  Year         Name  Count
# 16        CA   F  1910    Josephine     66
# 44        CA   F  1910         Jean     35
# 46        CA   F  1910       Jessie     32
# 59        CA   F  1910        Julia     28
# 66        CA   F  1910      Juanita     25
# ...      ...  ..   ...          ...    ...
# 387597    CA   M  2019  Joseantonio      5
# 387598    CA   M  2019       Jovian      5
# 387599    CA   M  2019       Jujhar      5
# 387600    CA   M  2019      Jullian      5
# 387601    CA   M  2019         June      5
#
# [33400 rows x 5 columns]

# %%
type(babyNames["Name"])
# Out:
# pandas.core.series.Series

# %%
type(babyNames["Name"].str)
# Out:
# pandas.core.strings.accessor.StringMethods

# %%
internalList = [i for i, m in sorted(enumerate(babyNames['Name']),  key=lambda x: -len(x[1]) )  ]
internalList
# Out:
# [102493,
#  301497,
#  302930,
#  305837,
#  310744,
#  310865,
#  316309,
#  316422,
#  323115,
#  326250,
#  326425,
#  328420,
#  333388,
#  71320,
#  73530,
#  90745,
#  96000,
#  96421,
#  98645,
#  101249,
#  101837,
#  102097,
#  102511,
#  103862,
#  104216,
#  104579,
#  107644,
#  107964,
#  108181,
#  110356,
#  111188,
#  111391,
#  112221,
#  114133,
#  114134,
#  117812,
#  119892,
#  119906,
#  121841,
#  122855,
#  125598,
#  126531,
#  129515,
#  130025,
#  130607,
#  133018,
#  133624,
#  135720,
#  136883,
#  139492,
#  140186,
#  142970,
#  147508,
#  148440,
#  150559,
#  151803,
#  154062,
#  154981,
#  158760,
#  159128,
#  162284,
#  163342,
#  166773,
#  167303,
#  170025,
#  172296,
#  174359,
#  178935,
#  183247,
#  184070,
#  187788,
#  188322,
#  192470,
#  196839,
#  200895,
#  205397,
#  209391,
#  213354,
#  296992,
#  298768,
#  300980,
#  303168,
#  305907,
#  305908,
#  307747,
#  307786,
#  310951,
#  313484,
#  313825,
#  315179,
#  318174,
# ...

# %%
len(internalList)
# Out:
# 387781

# %%
babyNames.iloc[[i for i, m in sorted(enumerate(babyNames['Name']),  key=lambda x: -len(x[1]) )  ]].head(5)
# Out:
#        State Sex  Year             Name  Count
# 102493    CA   F  1986  Mariadelosangel      5
# 301497    CA   M  1987  Franciscojavier      5
# 302930    CA   M  1988  Franciscojavier     10
# 305837    CA   M  1989  Franciscojavier      6
# 310744    CA   M  1991  Ryanchristopher      7

# %%
babyNameLen = babyNames["Name"].str.len()

# %%
babyNameLen
# Out:
# 0         4
# 1         5
# 2         7
# 3         8
# 4         7
#          ..
# 387776    7
# 387777    4
# 387778    6
# 387779    4
# 387780    5
# Name: Name, Length: 387781, dtype: int64

# %%
babyNames["NameLen"] = babyNameLen

# %%
babyNames.head()
# Out:
#   State Sex  Year      Name  Count  NameLen
# 0    CA   F  1910      Mary    295        4
# 1    CA   F  1910     Helen    239        5
# 2    CA   F  1910   Dorothy    220        7
# 3    CA   F  1910  Margaret    163        8
# 4    CA   F  1910   Frances    134        7

# %%
sortedBabyNames = babyNames.sort_values("NameLen", ascending=True)

# %%
babyNames = babyNames.drop("NameLen", axis=1)

# %%
babyNames.head(10)
# Out:
#   State Sex  Year       Name  Count
# 0    CA   F  1910       Mary    295
# 1    CA   F  1910      Helen    239
# 2    CA   F  1910    Dorothy    220
# 3    CA   F  1910   Margaret    163
# 4    CA   F  1910    Frances    134
# 5    CA   F  1910       Ruth    128
# 6    CA   F  1910     Evelyn    126
# 7    CA   F  1910      Alice    118
# 8    CA   F  1910   Virginia    101
# 9    CA   F  1910  Elizabeth     93

# %%
sortedBabyNames.tail(10)
# Out:
#        State Sex  Year             Name  Count  NameLen
# 333388    CA   M  2000  Franciscojavier      6       15
# 326425    CA   M  1997  Ryanchristopher      5       15
# 305837    CA   M  1989  Franciscojavier      6       15
# 326250    CA   M  1997  Franciscojavier      5       15
# 102493    CA   F  1986  Mariadelosangel      5       15
# 316309    CA   M  1993  Johnchristopher      5       15
# 302930    CA   M  1988  Franciscojavier     10       15
# 323115    CA   M  1996  Franciscojavier      8       15
# 310865    CA   M  1991  Franciscojavier      6       15
# 310744    CA   M  1991  Ryanchristopher      7       15

# %%
sortedBabyNames.head(10)
# Out:
#        State Sex  Year Name  Count  NameLen
# 384451    CA   M  2018   Jr      6        2
# 303608    CA   M  1988   Yu      6        2
# 303599    CA   M  1988   Vi      6        2
# 133248    CA   F  1995   Ka     10        2
# 89494     CA   F  1982   Jo     19        2
# 291124    CA   M  1982   Kc      9        2
# 268904    CA   M  1967   Al     23        2
# 247335    CA   M  1946   Ed     47        2
# 104753    CA   F  1987   Mi      8        2
# 297392    CA   M  1985   Le      5        2

# %%
# approach 2
babyNameLen
# Out:
# 0         4
# 1         5
# 2         7
# 3         8
# 4         7
#          ..
# 387776    7
# 387777    4
# 387778    6
# 387779    4
# 387780    5
# Name: Name, Length: 387781, dtype: int64

# %%
sortedNameLen = babyNameLen.sort_values()

# %%
sortedNameLen
# Out:
# 384451     2
# 303608     2
# 303599     2
# 133248     2
# 89494      2
#           ..
# 316309    15
# 302930    15
# 323115    15
# 310865    15
# 310744    15
# Name: Name, Length: 387781, dtype: int64

# %%
indexSortedNameLen = sortedNameLen.index

# %%
indexSortedNameLen
# Out:
# Index([384451, 303608, 303599, 133248,  89494, 291124, 268904, 247335, 104753,
#        297392,
#        ...
#        333388, 326425, 305837, 326250, 102493, 316309, 302930, 323115, 310865,
#        310744],
#       dtype='int64', length=387781)

# %%
babyNames.loc[indexSortedNameLen].head(5)
# Out:
#        State Sex  Year Name  Count
# 384451    CA   M  2018   Jr      6
# 303608    CA   M  1988   Yu      6
# 303599    CA   M  1988   Vi      6
# 133248    CA   F  1995   Ka     10
# 89494     CA   F  1982   Jo     19

# %%
# popularity
babyNames.query("Name == 'Jennifer'").sort_values("Year")
# Out:
#        State Sex  Year      Name  Count
# 13609     CA   F  1934  Jennifer      5
# 16324     CA   F  1938  Jennifer      5
# 16992     CA   F  1939  Jennifer      6
# 17532     CA   F  1940  Jennifer     13
# 18209     CA   F  1941  Jennifer     24
# ...      ...  ..   ...       ...    ...
# 209753    CA   F  2015  Jennifer    242
# 213692    CA   F  2016  Jennifer    239
# 217566    CA   F  2017  Jennifer    226
# 221365    CA   F  2018  Jennifer    167
# 225103    CA   F  2019  Jennifer    145
#
# [121 rows x 5 columns]

# %%
jennifyNamesSortedByYear = babyNames.query("Name == 'Jennifer'").sort_values("Year")

# %%
jennifyNamesSortedByYear["Count"]
# Out:
# 13609       5
# 16324       5
# 16992       6
# 17532      13
# 18209      24
#          ...
# 209753    242
# 213692    239
# 217566    226
# 221365    167
# 225103    145
# Name: Count, Length: 121, dtype: int64

# %%
max(jennifyNamesSortedByYear["Count"])
# Out:
# 6064

# %%
min(jennifyNamesSortedByYear["Count"])
# Out:
# 5

# %%
def ammd(series):
    # print("running ammd")
    return max(series) - min(series)

# %%
ammd(jennifyNamesSortedByYear["Count"])
# Out:
# 6059

# %%
jennifer_count = babyNames.query("Name == 'Jennifer'")["Count"]

# %%
min(jennifer_count)
# Out:
# 5

# %%
ammd(jennifer_count)
# Out:
# 6059

# %%
babyNamesReduced = babyNames.drop("State", axis=1)
babyNamesReduced = babyNamesReduced.drop("Sex", axis=1)
babyNamesReduced = babyNamesReduced.drop("Year", axis=1)

groupByNames = babyNamesReduced.groupby("Name")

# %%
babyNamesReduced.groupby("Name").agg([ammd, min, max])
# Out:
# /var/folders/m0/wj79nd7n7_j03g4gcc4pdlnc0000gn/T/ipykernel_66108/3626372053.py:1: FutureWarning: The provided callable <built-in function min> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   babyNamesReduced.groupby("Name").agg([ammd, min, max])
# /var/folders/m0/wj79nd7n7_j03g4gcc4pdlnc0000gn/T/ipykernel_66108/3626372053.py:1: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   babyNamesReduced.groupby("Name").agg([ammd, min, max])
#         Count
#          ammd min  max
# Name
# Aadan       2   5    7
# Aadarsh     0   6    6
# Aaden     148  10  158
# Aadhav      2   6    8
# Aadhira     4   6   10
# ...       ...  ..  ...
# Zylah       7   5   12
# Zyler       5   5   10
# ...

# %%
import seaborn as sns

# %%
df = sns.load_dataset('titanic')

# %%
df.head(10)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0         0       3    male  22.0      1      0   7.2500        S   Third
# 1         1       1  female  38.0      1      0  71.2833        C   First
# 2         1       3  female  26.0      0      0   7.9250        S   Third
# 3         1       1  female  35.0      1      0  53.1000        S   First
# 4         0       3    male  35.0      0      0   8.0500        S   Third
# 5         0       3    male   NaN      0      0   8.4583        Q   Third
# 6         0       1    male  54.0      0      0  51.8625        S   First
# 7         0       3    male   2.0      3      1  21.0750        S   Third
# 8         1       3  female  27.0      0      2  11.1333        S   Third
# 9         1       2  female  14.0      1      0  30.0708        C  Second
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# ...

# %%
df['fare'].agg(['sum', 'mean', 'min', 'max'])
# Out:
# sum     28693.949300
# mean       32.204208
# min         0.000000
# max       512.329200
# Name: fare, dtype: float64

# %%
df['fare'].agg(ammd)
# Out:
# 512.3292

# %%
df = pd.DataFrame({'A' : ['foo', 'bar', 'foo', 'bar','foo', 'bar'], 'B' : [1, 2, 3, 4, 5, 6], 'C' : [2.0, 5., 8., 1., 2., 9.]})

# %%
df
# Out:
#      A  B    C
# 0  foo  1  2.0
# 1  bar  2  5.0
# 2  foo  3  8.0
# 3  bar  4  1.0
# 4  foo  5  2.0
# 5  bar  6  9.0

# %%
df2 = pd.DataFrame({'A' : ['foo', 'bar', 'foo', 'bar','foo', 'bar'], 'B' : [4, 6, 10, 12, 15, 16], 'F' : [20, 25., 28., 10., 20., 90.]})

# %%
df2
# Out:
#      A   B     F
# 0  foo   4  20.0
# 1  bar   6  25.0
# 2  foo  10  28.0
# 3  bar  12  10.0
# 4  foo  15  20.0
# 5  bar  16  90.0

# %%
df3 = df.merge(df2)

# %%
df3
# Out:
#      A  B    C     F
# 0  bar  6  9.0  25.0

# %%
grouped = df.groupby('A')

# %%
grouped.agg([min, max, sum, len])
# Out:
# /var/folders/m0/wj79nd7n7_j03g4gcc4pdlnc0000gn/T/ipykernel_66108/974895691.py:1: FutureWarning: The provided callable <built-in function min> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   grouped.agg([min, max, sum, len])
# /var/folders/m0/wj79nd7n7_j03g4gcc4pdlnc0000gn/T/ipykernel_66108/974895691.py:1: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   grouped.agg([min, max, sum, len])
# ...

# %%
grouped.filter(lambda x: x['B'].mean() > 3.)
# Out:
#      A  B    C
# 1  bar  2  5.0
# 3  bar  4  1.0
# 5  bar  6  9.0

# %%
import numpy as np

# %%
babyPivot =babyNames.pivot_table(index='Year', columns='Sex', values='Count', aggfunc=np.max)
# Out:
# /var/folders/m0/wj79nd7n7_j03g4gcc4pdlnc0000gn/T/ipykernel_66108/3486214999.py:1: FutureWarning: The provided callable <function max at 0x1136e3ec0> is currently using DataFrameGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   babyPivot =babyNames.pivot_table(index='Year', columns='Sex', values='Count', aggfunc=np.max)

# %%
babyPivot.sort_values("Year")
# Out:
# Sex      F     M
# Year
# 1910   295   237
# 1911   390   214
# 1912   534   501
# 1913   584   614
# 1914   773   769
# ...    ...   ...
# 2015  2956  2773
# 2016  2799  2694
# 2017  2740  2527
# 2018  2741  2567
# 2019  2592  2668
#
# [110 rows x 2 columns]

# %%
type(babyPivot)
# Out:
# pandas.core.frame.DataFrame

# %%
 babyNames.query("Year == 1910")
# Out:
#        State Sex  Year      Name  Count
# 0         CA   F  1910      Mary    295
# 1         CA   F  1910     Helen    239
# 2         CA   F  1910   Dorothy    220
# 3         CA   F  1910  Margaret    163
# 4         CA   F  1910   Frances    134
# ...      ...  ..   ...       ...    ...
# 228618    CA   M  1910      Pete      5
# 228619    CA   M  1910   Russell      5
# 228620    CA   M  1910   Stephen      5
# 228621    CA   M  1910       Tom      5
# 228622    CA   M  1910    Virgil      5
#
# [363 rows x 5 columns]

# %%
import pandas as pd

# Creating a sample DataFrame
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eva'],
    'Age': [24, 27, 22, 32, 29],
    'City': ['New York', 'Los Angeles', 'Chicago', 'Houston', 'Phoenix']
}

df = pd.DataFrame(data)
print(df)
# Out:
#       Name  Age         City
# 0    Alice   24     New York
# 1      Bob   27  Los Angeles
# 2  Charlie   22      Chicago
# 3    David   32      Houston
# 4      Eva   29      Phoenix

# %%
# Selecting the first row using integer indexing
print(df.iloc[0])
# Out:
# Name       Alice
# Age           24
# City    New York
# Name: 0, dtype: object

# %%
# Selecting the first three rows using integer indexing
print(df.iloc[0:3])
# Out:
#       Name  Age         City
# 0    Alice   24     New York
# 1      Bob   27  Los Angeles
# 2  Charlie   22      Chicago
